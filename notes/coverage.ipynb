# %%
coverage run -m pytest 通过pytest来运行测试统计覆盖率
> 生成的不是.coverage,而是.coverage.DESKTOP-MH8F63B.20220.XMSQOxYx
> 这是因为你在并行模式下运行了 coverage（parallel = true），它会为每个进程生成一个带主机名和随机后缀的 .coverage.* 文件。
> 你需要合并这些文件，生成标准的 .coverage 文件，然后再运行 coverage report。
> coverage combine
> coverage report
